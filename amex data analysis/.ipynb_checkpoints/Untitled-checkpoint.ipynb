# %%
# linear algebra
import numpy as np
 
# data processing
import pandas as pd
 
# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
 
# Algorithms
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_curve, precision_recall_curve, auc, make_scorer, confusion_matrix, f1_score, fbeta_score, roc_auc_score
# Import the Naive Bayes, logistic regression, Bagging, RandomForest, AdaBoost, GradientBoost, Decision Trees and SVM Classifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %%
train = pd.read_csv("development_dataset.csv")
test1 = pd.read_csv("leaderboard_dataset.csv")
test2 = pd.read_csv("Evaluation_dataset.csv")

# %%
sns.pairplot(train)

# %%
train.shape

# %%
test1.shape

# %%
test2.shape

# %%
train.info()

# %%
test1.info()

# %%
test2.info()

# %%
data = [train]

for dataset in data:
    mean = train["VAR2"].mean()
    std = train["VAR2"].std()
    is_null = dataset["VAR2"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_var2 = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in Age column with random values generated
    age_slice = dataset["VAR2"].copy()
    age_slice[np.isnan(age_slice)] = rand_var2
    dataset["VAR2"] = age_slice
    dataset["VAR2"] = train["VAR2"].astype(float)
train["VAR2"].isnull().sum()

# %%
train.info()

# %%
train['VAR2'].head()

# %%
train.head()

# %%
train['VAR14'].describe()

# %%
data = [test1, test2]
for dataset in data:
    mean = test1["VAR2"].mean()
    std = test1["VAR2"].std()
    is_null = dataset["VAR2"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_var2 = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in Age column with random values generated
    age_slice = dataset["VAR2"].copy()
    age_slice[np.isnan(age_slice)] = rand_var2
    dataset["VAR2"] = age_slice
    dataset["VAR2"] = test1["VAR2"].astype(float)
test1["VAR2"].isnull().sum()

# %%
test1.info()

# %%
train.VAR14.unique()

# %%
train.VAR14.describe()

# %%
train["VAR14"] = train["VAR14"].replace('.', '13')

# %%
train.VAR14.unique()

# %%
train.VAR14.describe()

# %%
train["VAR14"] = train["VAR14"].astype(float)

# %%
train.VAR14.unique()

# %%
train.info()

# %%
test1.VAR14.describe()

# %%
test1.VAR14.unique()

# %%
test1["VAR14"] = test1["VAR14"].replace('.', '13')
test2["VAR14"] = test2["VAR14"].replace('.', '13')

# %%
test1.VAR14.unique()

# %%
test1.VAR14.describe()

# %%
test1["VAR14"] = test1["VAR14"].astype(float)
test2["VAR14"] = test2["VAR14"].astype(float)

# %%
test1.VAR14.unique()

# %%
test1.info()

# %%
data = [train,test1]
columns = ["VAR3","VAR4","VAR6","VAR7","VAR8","VAR9","VAR10","VAR11","VAR12","VAR13","VAR15","VAR16","VAR17"]
for dataset in data:
    for x in columns:
        mean = dataset[x].mean()
        std = dataset[x].std()
        is_null = dataset[x].isnull().sum()
        # compute random numbers between the mean, std and is_null
        rand_var2 = np.random.randint(mean - std, mean + std, size = is_null)
        # fill NaN values in Age column with random values generated
        age_slice = dataset[x].copy()
        age_slice[np.isnan(age_slice)] = rand_var2
        dataset[x] = age_slice
        dataset[x] = dataset[x].astype(float)
dataset[x].isnull().sum()

# %%
train.info()

# %%
test1.info()

# %%
test1.head()

# %%
data = [train]
for dataset in data:
    mean = train["VAR5"].mean()
    std = train["VAR5"].std()
    is_null = dataset["VAR5"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_var2 = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in Age column with random values generated
    age_slice = dataset["VAR5"].copy()
    age_slice[np.isnan(age_slice)] = rand_var2
    dataset["VAR5"] = age_slice
    dataset["VAR5"] = train["VAR5"].astype(float)
train["VAR5"].isnull().sum()

# %%
train.VAR5.head(20)

# %%
train.info()

# %%
credit_line = {"Low": 1, "Medium": 2, "High": 3}
train["VAR21"] = train["VAR21"].map(credit_line)
train.head(20)

# %%
train["VAR21"] = train["VAR21"].astype(float)

# %%
train.head(20)

# %%
train.info()

# %%
test1.info()

# %%
train = train.drop(["VAR17"], axis=1)
#train = train.drop(["VAR9"], axis=1)
#train = train.drop(["VAR4"], axis=1)

# %%
test1 = test1.drop(["VAR17"], axis=1)
#test1 = test1.drop(["VAR9"], axis=1)
#test1 = test1.drop(["VAR4"], axis=1)

# %%
train = train.drop(["VAR1"], axis=1)
X_train = train.drop("VAR21", axis=1)
Y_train = train["VAR21"]
#Y_train = label_binarize(Y_train, classes=[1, 2, 3])
X_test1  = test1.drop("VAR1", axis=1).copy()

# %%
Y_train

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)

Y_pred5 = logreg.predict(X_test1)

acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
print (acc_log)
# Out:
# C:\Users\Shridam\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Shridam\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 55.08

# %%
predictions5 = Y_pred5
submission = pd.DataFrame({'no.':test1['VAR1'], 'cl':predictions5})
credit_line_reverse = {1.0: "Low", 2.0 : "Medium", 3.0 : "High"}
submission["cl"] = submission["cl"].map(credit_line_reverse)
submission.head(20)
# Out:
#     no.      cl
# 0     1     Low
# 1     2  Medium
# 2     3  Medium
# 3     4  Medium
# 4     5  Medium
# 5     6  Medium
# 6     7  Medium
# 7     8  Medium
# 8     9  Medium
# 9    10  Medium
# 10   11  Medium
# 11   12  Medium
# 12   13  Medium
# 13   14  Medium
# 14   15     Low
# 15   16  Medium
# 16   17  Medium
# 17   18  Medium
# 18   19  Medium
# 19   20  Medium

# %%
filename = 'Ezio_IITGuwahati_6.csv'
submission.to_csv(filename, index = False)
print('saved file: ' + filename)
# Out:
# saved file: Ezio_IITGuwahati_6.csv

# %%
train = train.drop(["VAR9"], axis=1)

test1 = test1.drop(["VAR9"], axis=1)

# %%
train.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1  911.764706  0.027778  430.000000  611.574748  8.181818  1.344479
# 2  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3  892.941177  4.000000  179.000000  638.076431  9.090909  0.820218
# 4  914.117647  0.083333  115.000000  626.514988  5.181818  1.372928
#
#          VAR8      VAR10      VAR11       VAR12  VAR13  VAR14  VAR15  \
# 0  198.113469  58.632548   0.279273  100.083403    1.0    1.0    1.0
# 1  198.600020  49.000000  10.000000   15.012510   11.0    1.0   20.0
# 2  197.267767  58.632548   0.453212  210.175146   10.0    1.0   10.0
# 3  197.355744  58.632548   4.000000   27.000000    1.0    1.0    3.0
# 4  198.790477  58.632548   1.000000  210.175146    1.0   13.0   17.0
#
#       VAR16  VAR18  VAR19       VAR20  VAR21
# 0  1.540594      1      0  100.104991    1.0
# 1  1.614613      0      1  146.654045    3.0
# 2  1.044599      0      0   98.249570    2.0
# 3  1.145729      1      0  140.862306    1.0
# 4  1.558341      1      0  101.268503    3.0

# %%
X_train = train.drop("VAR21", axis=1)
Y_train = train["VAR21"]
X_test1  = test1.drop("VAR1", axis=1).copy()
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)

Y_pred6 = logreg.predict(X_test1)

acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
print (acc_log)
# Out:
# C:\Users\Shridam\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Shridam\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 55.03

# %%
predictions6 = Y_pred6
submission = pd.DataFrame({'no.':test1['VAR1'], 'cl':predictions5})
credit_line_reverse = {1.0: "Low", 2.0 : "Medium", 3.0 : "High"}
submission["cl"] = submission["cl"].map(credit_line_reverse)
filename = 'Ezio_IITGuwahati_7.csv'
submission.to_csv(filename, index = False)
print('saved file: ' + filename)
# Out:
# saved file: Ezio_IITGuwahati_7.csv

# %%
adaboost = AdaBoostClassifier()
# Fit our model to the training data
adaboost.fit(X_train, Y_train)
# Predict on the test data
adaboost_predictions = adaboost.predict(X_test1)
Y_pred8 = adaboost_predictions
acc_adaboost = round(adaboost.score(X_train, Y_train) * 100, 2)
print (acc_adaboost)
# Out:
# 56.81

# %%
predictions8 = Y_pred8
submission = pd.DataFrame({'no.':test1['VAR1'], 'cl':predictions8})
credit_line_reverse = {1.0: "Low", 2.0 : "Medium", 3.0 : "High"}
submission["cl"] = submission["cl"].map(credit_line_reverse)
filename = 'Ezio_IITGuwahati_9.csv'
submission.to_csv(filename, index = False, header = None)
print('saved file: ' + filename)
# Out:
# saved file: Ezio_IITGuwahati_9.csv

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()
xg.fit(X_train, Y_train)
xg_predictions = xg.predict(X_test1)
Y_pred9 = xg_predictions
acc_xg = round(xg.score(X_train, Y_train) * 100, 2)
print (acc_xg)
# Out:
# 58.55

# %%
predictions9 = Y_pred9
submission = pd.DataFrame({'no.':test1['VAR1'], 'cl':predictions9})
credit_line_reverse = {1.0: "Low", 2.0 : "Medium", 3.0 : "High"}
submission["cl"] = submission["cl"].map(credit_line_reverse)
filename = 'Ezio_IITGuwahati_10.csv'
submission.to_csv(filename, index = False, header = None)
print('saved file: ' + filename)
# Out:
# saved file: Ezio_IITGuwahati_10.csv

# %%
param_test1 = {
    'n_estimators': [100,200,500,750,1000],
    'max_depth': [3,5,7,9],
    'min_child_weight': [1,3,5],
    'gamma':[i/10.0 for i in range(0,5)],
    'subsample':[i/10.0 for i in range(6,10)],
    'colsample_bytree':[i/10.0 for i in range(6,10)],
    'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05, 0.1, 1],
    'learning_rate': [0.01, 0.02, 0.05, 0.1]
}
scoring = { 'Accuracy': make_scorer(accuracy_score)}
gsearch1 = GridSearchCV(estimator = XGBClassifier(), 
                       param_grid = param_test1, 
                       scoring=scoring, iid=False,
                       cv=5, verbose = 5, 
                       refit='Accuracy')
gsearch1.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 134400 candidates, totalling 672000 fits
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=0.6
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=0.6, Accuracy=0.5588062334607469, total=  10.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=0.6
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.4s remaining:    0.0s
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=0.6, Accuracy=0.5609469195706513, total=  10.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=0
9s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, subsample=0.7
# ...
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.6, Accuracy=0.5647889395499338, total=  33.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.6, Accuracy=0.566112663627004, total=  32.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7, Accuracy=0.5746839164951485, total=  32.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7, Accuracy=0.5771210116159389, total=  34.1s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7, Accuracy=0.5769966171495808, total=  33.5s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7, Accuracy=0.5658185027209883, total=  30.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.7, Accuracy=0.566848065892043, total=  36.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8, Accuracy=0.5735077918259336, total=  36.5s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8, Accuracy=0.5757976768122335, total=  32.5s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8, Accuracy=0.5778790998676276, total=  31.7s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8, Accuracy=0.5640535372848948, total=  31.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.8, Accuracy=0.5656714222679806, total=  31.9s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9, Accuracy=0.5732137606586298, total=  30.1s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9, Accuracy=0.5744743420085282, total=  28.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9, Accuracy=0.577584938961612, total=  29.9s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9, Accuracy=0.5650831004559494, total=  28.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0, subsample=0.9, Accuracy=0.5658185027209883, total=  28.2s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6, Accuracy=0.5746839164951485, total=  31.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6, Accuracy=0.5757976768122335, total=  30.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6, Accuracy=0.577584938961612, total=  29.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6, Accuracy=0.5647889395499338, total=  30.9s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.6, Accuracy=0.566112663627004, total=  31.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7, Accuracy=0.5746839164951485, total=  30.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7, Accuracy=0.5771210116159389, total=  28.7s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7, Accuracy=0.5767024562435652, total=  31.1s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7, Accuracy=0.5658185027209883, total=  29.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.7, Accuracy=0.566848065892043, total=  29.1s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8, Accuracy=0.5735077918259336, total=  28.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8, Accuracy=0.5757976768122335, total=  30.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8, Accuracy=0.5781732607736432, total=  31.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8, Accuracy=0.5640535372848948, total=  27.8s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.8, Accuracy=0.5656714222679806, total=  29.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9, Accuracy=0.5730667450749779, total=  29.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9, Accuracy=0.5744743420085282, total=  29.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9, Accuracy=0.5777320194146198, total=  27.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9, Accuracy=0.565377261361965, total=  28.6s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.001, subsample=0.9, Accuracy=0.5658185027209883, total=  30.2s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6, Accuracy=0.5745369009114967, total=  30.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6, Accuracy=0.5756506396118218, total=  30.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6, Accuracy=0.5777320194146198, total=  31.2s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6, Accuracy=0.5652301809089572, total=  31.7s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.6, Accuracy=0.5658185027209883, total=  30.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7, Accuracy=0.574095854160541, total=  30.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7, Accuracy=0.5771210116159389, total=  30.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7, Accuracy=0.5767024562435652, total=  32.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7, Accuracy=0.5658185027209883, total=  29.5s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.7, Accuracy=0.566112663627004, total=  31.0s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.8, Accuracy=0.5735077918259336, total=  29.4s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.8
# [CV]  colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.8, Accuracy=0.5759447140126452, total=  28.3s
# [CV] colsample_bytree=0.6, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=750, reg_alpha=0.005, subsample=0.8

# %%
# Instantiate our model
xg = XGBClassifier(learning_rate=0.01, n_estimators=750,
                   max_depth= 3, min_child_weight= 1, 
                   colsample_bytree= 0.6, gamma= 0.0, 
                   reg_alpha= 0.001, subsample= 0.8
                  )
xg.fit(X_train, Y_train)
xg_predictions = xg.predict(X_test)
Y_pred10 = xg_predictions
acc_xg = round(xg.score(X_train, Y_train) * 100, 2)
print (acc_xg)

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()
xg.fit(X_train, Y_train)
xg_predictions = xg.predict(X_test1)
Y_pred9 = xg_predictions
acc_xg = round(xg.score(X_train, Y_train) * 100, 2)
print (acc_xg)
# Out:
# 58.2
